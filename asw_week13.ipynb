# %% [markdown]
# <a href="https://colab.research.google.com/github/YunseoChoe/2025-ASW-LLM/blob/main/asw_week13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
OPENAI_API_KEY=""

# %%
pip install openai==0.28

# %%
# 건물
import openai
import requests
from PIL import Image
from io import BytesIO

# Set your OpenAI API key
openai.api_key = OPENAI_API_KEY

def generate_image(prompt):
  response = openai.Image.create(
      prompt=prompt,
      n=1, # Number of images to generate
      size="1024x1024" # Size of the generated image
  )
  image_url = response['data'][0]['url']
  return image_url

def save_image(image_url, filename) :
  response = requests.get(image_url)
  image = Image.open(BytesIO(response.content))
  image.save(filename)

prompt = "A futuristic cityscape at sunset"
image_url = generate_image(prompt)
print (f"Image URL: {image_url}")
save_image (image_url, "generated_image.png" )
print ("Image saved as generated_image.png" )
# Out:
# Image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-5ry0LkkMcAL21sBYTbBI948C/user-Ta358DHvAB0VtotAWl38aFTt/img-eapALWB3sgiMqfOyC89VZ3IJ.png?st=2025-11-25T04%3A51%3A18Z&se=2025-11-25T06%3A51%3A18Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=31d50bd4-689f-439b-a875-f22bd677744d&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-11-25T05%3A51%3A18Z&ske=2025-11-26T05%3A51%3A18Z&sks=b&skv=2024-08-04&sig=QqArMaBR7Goh0V2lE5IdA9wqFVm5skpVs5DPb7qmsok%3D
# Image saved as generated_image.png

# %%
# 고양이
import openai
import requests
from PIL import Image
from io import BytesIO

openai.api_key = OPENAI_API_KEY

def generate_image(prompt):
    response = openai.Image.create(
        model="dall-e-3",
        prompt=prompt,
        n=1,
        size="1024x1024",
        quality="standard"
    )
    image_url = response['data'][0]['url']
    return image_url

def save_image(image_url, filename):
    response = requests.get(image_url)
    image = Image.open(BytesIO(response.content))
    image.save(filename)

# Example prompt
prompt = "A white siamese cat"

# Generate image
image_url = generate_image(prompt)
print(f"Image URL: {image_url}")

# Save image to file
save_image(image_url, "generated_image.png")
print("Image saved as generated_image.png")
# Out:
# Image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-5ry0LkkMcAL21sBYTbBI948C/user-Ta358DHvAB0VtotAWl38aFTt/img-eXOzbkUZTO2796KuVe2f9rLN.png?st=2025-11-25T04%3A52%3A48Z&se=2025-11-25T06%3A52%3A48Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=0e2a3d55-e963-40c9-9c89-2a1aa28cb3ac&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-11-25T05%3A29%3A45Z&ske=2025-11-26T05%3A29%3A45Z&sks=b&skv=2024-08-04&sig=6ntYR4HRpX0MWi87JIqO5dPLuopLp5YzoqaRme7eIcg%3D
# Image saved as generated_image.png

# %%
# codex
import openai

openai.api_key = OPENAI_API_KEY

def generate_code(prompt, model="gpt-3.5-turbo-instruct", max_tokens=1000):
    """
    OpenAI Codex 모델을 사용해 코드를 생성하는 함수
    """
    try:
        response = openai.Completion.create(
            model=model,
            prompt=prompt,
            max_tokens=max_tokens,
            temperature=0,
            n=1,
            stop=None
        )
        # 생성된 코드 추출
        code = response.choices[0].text.strip()
        return code
    except Exception as e:
        print(f"An error occurred: {str(e)}")
        return None

# Example prompt
prompt = "Write a C code that computes Fibonacci number using memoization."

# Generate code
generated_code = generate_code(prompt)

# Print the generated code
if generated_code:
    print("Generated Code:\n")
    print(generated_code)
else:
    print("Failed to generate code.")
# Out:
# Generated Code:
#
# #include <stdio.h>
#
# // Function to compute Fibonacci number using memoization
# int fib(int n, int memo[])
# {
#     // Base cases
#     if (n == 0 || n == 1)
#         return n;
#
#     // Check if the value is already computed
#     if (memo[n] != -1)
#         return memo[n];
#
#     // Compute and store the value in the memo array
#     memo[n] = fib(n-1, memo) + fib(n-2, memo);
#
#     // Return the computed value
#     return memo[n];
# }
#
# int main()
# {
#     int n;
#     printf("Enter the value of n: ");
#     scanf("%d", &n);
#
#     // Initialize the memo array with -1
#     int memo[n+1];
#     for (int i = 0; i <= n; i++)
#         memo[i] = -1;
#
#     // Call the fib function and print the result
#     printf("Fibonacci number at position %d is %d", n, fib(n, memo));
#
#     return 0;
# }
#
# /*
# Output:
#
# Enter the value of n: 6
# Fibonacci number at position 6 is 8
# */

# %%
# file
