# %% [markdown]
# <a href="https://colab.research.google.com/github/YunseoChoe/2025-ASW-LLM/blob/main/asw_week11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai==0.28
# Out:
# ...
#   Using cached openai-0.28.0-py3-none-any.whl.metadata (13 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 3.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 1.109.1
#     Uninstalling openai-1.109.1:
#       Successfully uninstalled openai-1.109.1
# ...

# %%
import openai

# %%
# openai API 키 인증
OPENAI_API_KEY = ""
openai.api_key = OPENAI_API_KEY
# 사용 가능한 모델 (2024-07월 초)
# gpt-4o-2024-05-13
# gpt-4o
# gpt-4-turbo-preview
# gpt-4-1106-preview
# gpt-4-0613
# gpt-4-0125-preview
# gpt-4
# gpt-3.5-turbo-16k
# gpt-3.5-turbo-1106
# gpt-3.5-burbo-0125
# gpt-3.5-turbo
model = "gpt-3.5-turbo-0125"

# %%
# 질문 작성하기
query = "프랑스의 수도를 알려줘."

# 메시지 설정하기
messages = [{
  "role": "user",
  "content": query
}]

# %%
# ChatGPT API를 이용한 ChatGPT 사용하기
response = openai.ChatCompletion.create(
model=model,
messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# 프랑스의 수도는 파리(Paris)입니다.

# %%
# 메시지 설정하기
messages = [{
"role": "system",
"content": "You are a helpful assistant."
},
 {
"role": "user",
"content": query
}]

# %%
response = openai.ChatCompletion.create(
model=model,
messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# 프랑스의 수도는 파리야! 에펠탑과 루브르 박물관이 있는 곳이죠. 그리고 로맨틱한 강이 흐르는 도시랍니다.

# %%
# 메시지 설정하기
messages = [{
"role": "system",
"content": "You are a humorous assistant."
}, {
"role": "user",
"content": query
}]

# %%
response = openai.ChatCompletion.create(
model=model,
messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# 프랑스의 수도는 파리야! 에펠탑이 있는 그곳이죠. 아름다운 도시입니다.
